# %%
import pandas as pd

# %%
df = pd.read_csv("../data/social_media_vs_productivity.csv")
df.shape
# Out:
# (30000, 19)

# %%
df.sample(5)
# Out:
#        age  gender job_type  daily_social_media_time  \
# 15026   48    Male  Finance                 0.189947
# 19439   26   Other  Student                 5.128585
# 15404   34  Female   Health                 6.252961
# 22589   41  Female  Student                 0.193693
# 27634   45  Female       IT                 0.000000
#
#       social_platform_preference  number_of_notifications  work_hours_per_day  \
# 15026                   Telegram                       61            5.478765
# 19439                   Telegram                       63            7.370921
# 15404                   Telegram                       55            6.901709
# 22589                    Twitter                       53           10.383973
# 27634                   Facebook                       57            3.270398
#
#        perceived_productivity_score  actual_productivity_score  stress_level  \
# 15026                      3.181837                   2.340916           7.0
# ...
