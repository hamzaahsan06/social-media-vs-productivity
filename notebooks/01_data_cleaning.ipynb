# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/screentime_and_stress.csv")
df.shape
# Out:
# (15000, 13)

# %%
df.sample(5)
# Out:
#       user_id  age  gender         occupation  daily_screen_time_hours  \
# 2483     2484   20  Female  Software Engineer                     6.54
# 6955     6956   53  Female            Teacher                     5.49
# 4098     4099   20  Female             Doctor                     9.52
# 9898     9899   53    Male            Manager                     3.59
# 1915     1916   35  Female            Student                     9.86
#
#       phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 2483                                58                  6.48
# 6955                               118                  6.88
# 4098                                15                  5.79
# 9898                                53                  6.87
# 1915                                38                  4.12
#
#       sleep_quality_score  stress_level  caffeine_intake_cups  \
# 2483                 6.91          6.54                     3
# 6955                 5.46          7.65                     1
# 4098                 5.77          9.79                     0
# 9898                 7.25          4.67                     1
# 1915                 3.82         10.00                     4
#
#       physical_activity_minutes  notifications_received_per_day  \
# 2483                         76                              93
# 6955                         76                             180
# 4098                         26                              30
# 9898                          9                              48
# 1915                         46                             245
#
#       mental_fatigue_score
# 2483                  6.31
# 6955                  6.71
# 4098                  8.01
# 9898                  6.12
# 1915                  9.65

# %%
df.isnull().sum()
# Out:
# user_id                             0
# age                                 0
# gender                              0
# occupation                          0
# daily_screen_time_hours             0
# phone_usage_before_sleep_minutes    0
# sleep_duration_hours                0
# sleep_quality_score                 0
# stress_level                        0
# caffeine_intake_cups                0
# physical_activity_minutes           0
# notifications_received_per_day      0
# mental_fatigue_score                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           15000 non-null  int64
#  1   age                               15000 non-null  int64
#  2   gender                            15000 non-null  str
#  3   occupation                        15000 non-null  str
#  4   daily_screen_time_hours           15000 non-null  float64
#  5   phone_usage_before_sleep_minutes  15000 non-null  int64
#  6   sleep_duration_hours              15000 non-null  float64
#  7   sleep_quality_score               15000 non-null  float64
#  8   stress_level                      15000 non-null  float64
#  9   caffeine_intake_cups              15000 non-null  int64
#  10  physical_activity_minutes         15000 non-null  int64
#  11  notifications_received_per_day    15000 non-null  int64
#  12  mental_fatigue_score              15000 non-null  float64
# dtypes: float64(5), int64(6), str(2)
# memory usage: 1.5 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)
# Out:
#                                    user_id       age  daily_screen_time_hours  \
# user_id                           1.000000 -0.009833                 0.010960
# age                              -0.009833  1.000000                 0.009094
# daily_screen_time_hours           0.010960  0.009094                 1.000000
# phone_usage_before_sleep_minutes -0.003865 -0.007754                 0.004228
# sleep_duration_hours             -0.014394 -0.005847                -0.001838
# sleep_quality_score              -0.004342 -0.000466                -0.746531
# stress_level                      0.009981  0.002849                 0.879001
# caffeine_intake_cups              0.003379 -0.019182                 0.006128
# physical_activity_minutes         0.000799 -0.005827                 0.002899
# notifications_received_per_day   -0.003432 -0.001594                -0.003357
# mental_fatigue_score              0.005458  0.009724                 0.828368
#
#                                   phone_usage_before_sleep_minutes  \
# user_id                                                  -0.003865
# age                                                      -0.007754
# daily_screen_time_hours                                   0.004228
# phone_usage_before_sleep_minutes                          1.000000
# sleep_duration_hours                                     -0.012930
# sleep_quality_score                                      -0.335283
# stress_level                                              0.155330
# caffeine_intake_cups                                      0.004639
# physical_activity_minutes                                -0.012705
# notifications_received_per_day                           -0.000691
# mental_fatigue_score                                      0.150180
#
#                                   sleep_duration_hours  sleep_quality_score  \
# user_id                                      -0.014394            -0.004342
# age                                          -0.005847            -0.000466
# daily_screen_time_hours                      -0.001838            -0.746531
# phone_usage_before_sleep_minutes             -0.012930            -0.335283
# sleep_duration_hours                          1.000000             0.009990
# sleep_quality_score                           0.009990             1.000000
# stress_level                                 -0.004893            -0.857463
# caffeine_intake_cups                         -0.013682            -0.009033
# physical_activity_minutes                    -0.001118            -0.005857
# notifications_received_per_day                0.005343             0.003354
# mental_fatigue_score                         -0.011073            -0.808019
#
#                                   stress_level  caffeine_intake_cups  \
# user_id                               0.009981              0.003379
# age                                   0.002849             -0.019182
# daily_screen_time_hours               0.879001              0.006128
# phone_usage_before_sleep_minutes      0.155330              0.004639
# sleep_duration_hours                 -0.004893             -0.013682
# sleep_quality_score                  -0.857463             -0.009033
# stress_level                          1.000000              0.003458
# caffeine_intake_cups                  0.003458              1.000000
# physical_activity_minutes             0.009360              0.010249
# notifications_received_per_day       -0.002808              0.006762
# mental_fatigue_score                  0.948768             -0.002722
#
#                                   physical_activity_minutes  \
# user_id                                            0.000799
# age                                               -0.005827
# daily_screen_time_hours                            0.002899
# phone_usage_before_sleep_minutes                  -0.012705
# sleep_duration_hours                              -0.001118
# sleep_quality_score                               -0.005857
# stress_level                                       0.009360
# caffeine_intake_cups                               0.010249
# physical_activity_minutes                          1.000000
# notifications_received_per_day                     0.006069
# mental_fatigue_score                               0.010254
#
#                                   notifications_received_per_day  \
# user_id                                                -0.003432
# age                                                    -0.001594
# daily_screen_time_hours                                -0.003357
# phone_usage_before_sleep_minutes                       -0.000691
# sleep_duration_hours                                    0.005343
# sleep_quality_score                                     0.003354
# stress_level                                           -0.002808
# caffeine_intake_cups                                    0.006762
# physical_activity_minutes                               0.006069
# notifications_received_per_day                          1.000000
# mental_fatigue_score                                   -0.005077
#
#                                   mental_fatigue_score
# user_id                                       0.005458
# age                                           0.009724
# daily_screen_time_hours                       0.828368
# phone_usage_before_sleep_minutes              0.150180
# sleep_duration_hours                         -0.011073
# sleep_quality_score                          -0.808019
# stress_level                                  0.948768
# caffeine_intake_cups                         -0.002722
# physical_activity_minutes                     0.010254
# notifications_received_per_day               -0.005077
# mental_fatigue_score                          1.000000
